# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamtyagi577/DataScientist101/blob/main/Display_the_first_three_rows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = { 'employee_id' : [3,90,9,60,49,43],
         'name'        : ['Bob', 'Alice', 'Tatiana', 'Annabelle', 'John', 'Khaled'],
         'department'  : ['Operations', 'Sales', 'Engineering', 'InormationTechnology', 'HR', 'Admin'],
         'salary'      : [48675, 11096, 33805, 37678, 23793, 40454]}

employees = pd.DataFrame(data)

# %%
employees.head(3)
# Out:
#    employee_id     name   department  salary
# 0            3      Bob   Operations   48675
# 1           90    Alice        Sales   11096
# 2            9  Tatiana  Engineering   33805

# %%
employees.tail(3)
# Out:
#    employee_id       name            department  salary
# 3           60  Annabelle  InormationTechnology   37678
# 4           49       John                    HR   23793
# 5           43     Khaled                 Admin   40454

# %%
employees[:4]
# Out:
#    employee_id       name            department  salary
# 0            3        Bob            Operations   48675
# 1           90      Alice                 Sales   11096
# 2            9    Tatiana           Engineering   33805
# 3           60  Annabelle  InormationTechnology   37678

# %%
employees[:]
# Out:
#    employee_id       name            department  salary
# 0            3        Bob            Operations   48675
# 1           90      Alice                 Sales   11096
# 2            9    Tatiana           Engineering   33805
# 3           60  Annabelle  InormationTechnology   37678
# 4           49       John                    HR   23793
# 5           43     Khaled                 Admin   40454

# %%
employees.iloc[2:5]
# Out:
#    employee_id       name            department  salary
# 2            9    Tatiana           Engineering   33805
# 3           60  Annabelle  InormationTechnology   37678
# 4           49       John                    HR   23793
