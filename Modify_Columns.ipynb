# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamtyagi577/DataScientist101/blob/main/Modify_Columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Sample DataFrame
data = {'name'  : ['Jack', 'Piper', 'Mia', 'Ulysses'],
        'salary': [19666, 74754, 62509, 54866]}

# %%
# Create Data Frame
employees = pd.DataFrame(data)
employees
# Out:
#       name  salary
# 0     Jack   19666
# 1    Piper   74754
# 2      Mia   62509
# 3  Ulysses   54866

# %%
# Double the salary
employees['salary'] = employees['salary'] * 2
employees
# Out:
#       name  salary
# 0     Jack   39332
# 1    Piper  149508
# 2      Mia  125018
# 3  Ulysses  109732
